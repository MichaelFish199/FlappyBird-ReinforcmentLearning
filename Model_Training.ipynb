# %% [markdown]
# # Environment Setup

# %%
#!pip install gym gym-retro, opencv-python
#!pip install mss
#!pip install pydirectinput

# %%
# For monitoring agent
from stable_baselines3.common.monitor import Monitor
# To vectorize and frame stack
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack

# %%
# Running Environment_Setup.ipynb to setup custom Flappy_Bird environment.
# %run tools\Environment.py

# %%
LOG_DIR = './logs/'

# %%
# Creating environment 
env = Flappy_Bird()
env = Monitor(env, LOG_DIR)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, 4, channels_order='last')

# %% [markdown]
# # Setup Callback To Monitor Training Process

# %%
#!pip install stable-baselines3[extra]

# %%
# Import os for file path management
import os 
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'

# %%
callback = TrainAndLoggingCallback(check_freq=40_000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # Training Model

# %%
# Model
from stable_baselines3 import DQN

# %%
# parameters
parameters = {'buffer_size': 10_000, 
              'learning_starts': 1000, 
              "learning_rate":0.00006, 
              "batch_size":16,
              "target_update_interval":500, 
              "exploration_fraction":0.99, 
              "exploration_initial_eps":0.04,
              "exploration_final_eps":0.0001
             }

# %%
# Creating the model
model = DQN('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, **parameters)
# Out:
# Using cpu device

# %%
# Loading wages of other model
model.set_parameters("train/FlappyBird_DQN_Easy")
# Loading replay buffer
model.load_replay_buffer("train/buffer_FlappyBird_DQN_Easy")

# %%
# Training the model
model.learn(total_timesteps=80_000, callback=callback)
# Out:
# Logging to ./logs/DQN_12
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 9.75     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1        |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 39       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.0999   |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1        |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 108      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.0999   |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1        |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 140      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.0999   |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1        |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 186      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.0999   |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1        |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 225      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.0998   |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1        |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 271      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.0998   |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1        |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 299      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.0998   |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1        |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 347      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.0998   |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1        |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 374      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.0997   |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1        |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 426      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.0997   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1        |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 449      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.0997   |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1        |
# |    time_elapsed     | 274      |
# |    total_timesteps  | 490      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.0997   |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1        |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 533      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.0997   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1        |
# |    time_elapsed     | 324      |
# |    total_timesteps  | 585      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.0996   |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1        |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 634      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.0996   |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1        |
# |    time_elapsed     | 373      |
# |    total_timesteps  | 680      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.0996   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1        |
# |    time_elapsed     | 391      |
# |    total_timesteps  | 706      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1        |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 764      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1        |
# |    time_elapsed     | 449      |
# |    total_timesteps  | 831      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1        |
# |    time_elapsed     | 472      |
# |    total_timesteps  | 875      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.0995   |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1        |
# |    time_elapsed     | 496      |
# |    total_timesteps  | 921      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.0994   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1        |
# |    time_elapsed     | 520      |
# |    total_timesteps  | 970      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.0994   |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1        |
# |    time_elapsed     | 558      |
# |    total_timesteps  | 1063     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.23     |
# |    n_updates        | 15       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.0993   |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1        |
# |    time_elapsed     | 587      |
# |    total_timesteps  | 1123     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.319    |
# |    n_updates        | 30       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.0993   |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1        |
# |    time_elapsed     | 613      |
# |    total_timesteps  | 1176     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.05     |
# |    n_updates        | 43       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.0993   |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1        |
# |    time_elapsed     | 632      |
# |    total_timesteps  | 1212     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.08     |
# |    n_updates        | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.0992   |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1        |
# |    time_elapsed     | 658      |
# |    total_timesteps  | 1265     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 7.26     |
# |    n_updates        | 66       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.0992   |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1        |
# |    time_elapsed     | 693      |
# |    total_timesteps  | 1345     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.66     |
# |    n_updates        | 86       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.0992   |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1        |
# |    time_elapsed     | 729      |
# |    total_timesteps  | 1430     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 11.2     |
# |    n_updates        | 107      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.0991   |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1        |
# |    time_elapsed     | 746      |
# |    total_timesteps  | 1452     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 8.5      |
# |    n_updates        | 112      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.0991   |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1        |
# |    time_elapsed     | 770      |
# |    total_timesteps  | 1499     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 7.46     |
# |    n_updates        | 124      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.0991   |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1        |
# |    time_elapsed     | 793      |
# |    total_timesteps  | 1545     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.31     |
# |    n_updates        | 136      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.0991   |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1        |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 1588     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 10.7     |
# |    n_updates        | 146      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.099    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1        |
# |    time_elapsed     | 850      |
# |    total_timesteps  | 1671     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.25     |
# |    n_updates        | 167      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.099    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1        |
# |    time_elapsed     | 882      |
# |    total_timesteps  | 1745     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.66     |
# |    n_updates        | 186      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.0989   |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1        |
# |    time_elapsed     | 912      |
# |    total_timesteps  | 1813     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.502    |
# |    n_updates        | 203      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.0989   |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2        |
# |    time_elapsed     | 947      |
# |    total_timesteps  | 1896     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.93     |
# |    n_updates        | 223      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.0988   |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2        |
# |    time_elapsed     | 974      |
# |    total_timesteps  | 1955     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.34     |
# |    n_updates        | 238      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.0988   |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2        |
# |    time_elapsed     | 996      |
# |    total_timesteps  | 2000     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 17.2     |
# |    n_updates        | 249      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.0988   |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2        |
# |    time_elapsed     | 1023     |
# |    total_timesteps  | 2058     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 7.22     |
# |    n_updates        | 264      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.0988   |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2        |
# |    time_elapsed     | 1044     |
# |    total_timesteps  | 2096     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.531    |
# |    n_updates        | 273      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.0987   |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2        |
# |    time_elapsed     | 1075     |
# |    total_timesteps  | 2167     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 7.39     |
# |    n_updates        | 291      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.0987   |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2        |
# |    time_elapsed     | 1105     |
# |    total_timesteps  | 2232     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 9.72     |
# |    n_updates        | 307      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.0987   |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2        |
# |    time_elapsed     | 1126     |
# |    total_timesteps  | 2265     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 9.74     |
# |    n_updates        | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.0986   |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2        |
# |    time_elapsed     | 1153     |
# |    total_timesteps  | 2316     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.975    |
# |    n_updates        | 328      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.0986   |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2        |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 2349     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 1.01     |
# |    n_updates        | 337      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.0986   |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2        |
# |    time_elapsed     | 1195     |
# |    total_timesteps  | 2395     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.615    |
# |    n_updates        | 348      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.0986   |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1        |
# |    time_elapsed     | 1218     |
# |    total_timesteps  | 2435     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 9.31     |
# |    n_updates        | 358      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.0985   |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2        |
# |    time_elapsed     | 1244     |
# |    total_timesteps  | 2490     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 7.67     |
# |    n_updates        | 372      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.0985   |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1        |
# |    time_elapsed     | 1268     |
# |    total_timesteps  | 2537     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 9.45     |
# |    n_updates        | 384      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.0985   |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1        |
# |    time_elapsed     | 1295     |
# |    total_timesteps  | 2585     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.47     |
# |    n_updates        | 396      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.0984   |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1        |
# |    time_elapsed     | 1313     |
# |    total_timesteps  | 2613     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 1.73     |
# |    n_updates        | 403      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.0984   |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1        |
# |    time_elapsed     | 1335     |
# |    total_timesteps  | 2652     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.6      |
# |    n_updates        | 412      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.0984   |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1        |
# |    time_elapsed     | 1368     |
# |    total_timesteps  | 2718     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 2.09     |
# |    n_updates        | 429      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.0984   |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1        |
# |    time_elapsed     | 1392     |
# |    total_timesteps  | 2767     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.772    |
# |    n_updates        | 441      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.0983   |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1        |
# |    time_elapsed     | 1420     |
# |    total_timesteps  | 2828     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.98     |
# |    n_updates        | 456      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.0983   |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1        |
# |    time_elapsed     | 1452     |
# |    total_timesteps  | 2901     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.51     |
# |    n_updates        | 475      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.0982   |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 2        |
# |    time_elapsed     | 1487     |
# |    total_timesteps  | 2982     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 7.23     |
# |    n_updates        | 495      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.0982   |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 2        |
# |    time_elapsed     | 1515     |
# |    total_timesteps  | 3044     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 1.51     |
# |    n_updates        | 510      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.0982   |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2        |
# |    time_elapsed     | 1540     |
# |    total_timesteps  | 3093     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.28     |
# |    n_updates        | 523      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.0981   |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 2        |
# |    time_elapsed     | 1560     |
# |    total_timesteps  | 3132     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 5.17     |
# |    n_updates        | 532      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.0981   |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 2        |
# |    time_elapsed     | 1588     |
# |    total_timesteps  | 3191     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 1.82     |
# |    n_updates        | 547      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.0981   |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 2        |
# |    time_elapsed     | 1617     |
# |    total_timesteps  | 3250     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 2.57     |
# |    n_updates        | 562      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.098    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 2        |
# |    time_elapsed     | 1641     |
# |    total_timesteps  | 3298     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.436    |
# |    n_updates        | 574      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.098    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 2        |
# |    time_elapsed     | 1666     |
# |    total_timesteps  | 3347     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.14     |
# |    n_updates        | 586      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.098    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 2        |
# |    time_elapsed     | 1692     |
# |    total_timesteps  | 3395     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.32     |
# |    n_updates        | 598      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.098    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 2        |
# |    time_elapsed     | 1717     |
# |    total_timesteps  | 3445     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.89     |
# |    n_updates        | 611      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.0979   |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 2        |
# |    time_elapsed     | 1751     |
# |    total_timesteps  | 3518     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.58     |
# |    n_updates        | 629      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.0979   |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 2        |
# |    time_elapsed     | 1786     |
# |    total_timesteps  | 3592     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 1.62     |
# |    n_updates        | 647      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.0979   |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 2        |
# |    time_elapsed     | 1802     |
# |    total_timesteps  | 3616     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.76     |
# |    n_updates        | 653      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.0978   |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 2        |
# |    time_elapsed     | 1820     |
# |    total_timesteps  | 3648     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 2.13     |
# |    n_updates        | 661      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.0978   |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 2        |
# |    time_elapsed     | 1848     |
# |    total_timesteps  | 3705     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.15     |
# |    n_updates        | 676      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.0978   |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 2        |
# |    time_elapsed     | 1879     |
# |    total_timesteps  | 3773     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.29     |
# |    n_updates        | 693      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.0977   |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 2        |
# |    time_elapsed     | 1908     |
# |    total_timesteps  | 3831     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 5.72     |
# |    n_updates        | 707      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.0977   |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 2        |
# |    time_elapsed     | 1941     |
# |    total_timesteps  | 3900     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.748    |
# |    n_updates        | 724      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.0976   |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 2        |
# |    time_elapsed     | 1969     |
# |    total_timesteps  | 3960     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 10.1     |
# |    n_updates        | 739      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.0976   |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 2        |
# |    time_elapsed     | 1986     |
# |    total_timesteps  | 3984     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 8.04     |
# |    n_updates        | 745      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.0976   |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 2        |
# |    time_elapsed     | 2016     |
# |    total_timesteps  | 4049     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 5.74     |
# |    n_updates        | 762      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.0976   |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 2        |
# |    time_elapsed     | 2045     |
# |    total_timesteps  | 4115     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.77     |
# |    n_updates        | 778      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.0975   |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 2        |
# |    time_elapsed     | 2083     |
# |    total_timesteps  | 4206     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.68     |
# |    n_updates        | 801      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.0975   |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 2        |
# |    time_elapsed     | 2110     |
# |    total_timesteps  | 4262     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.24     |
# |    n_updates        | 815      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.0974   |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 2        |
# |    time_elapsed     | 2145     |
# |    total_timesteps  | 4345     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 1.74     |
# |    n_updates        | 836      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.0974   |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 2        |
# |    time_elapsed     | 2170     |
# |    total_timesteps  | 4396     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.34     |
# |    n_updates        | 848      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.0973   |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 2        |
# |    time_elapsed     | 2202     |
# |    total_timesteps  | 4466     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 7        |
# |    n_updates        | 866      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.0973   |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 2        |
# |    time_elapsed     | 2231     |
# |    total_timesteps  | 4525     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.753    |
# |    n_updates        | 881      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.0973   |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 2        |
# |    time_elapsed     | 2263     |
# |    total_timesteps  | 4595     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 1.42     |
# |    n_updates        | 898      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.0972   |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 2        |
# |    time_elapsed     | 2296     |
# |    total_timesteps  | 4666     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.38     |
# |    n_updates        | 916      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.0972   |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 2        |
# |    time_elapsed     | 2325     |
# |    total_timesteps  | 4729     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.47     |
# |    n_updates        | 932      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.0972   |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 2        |
# |    time_elapsed     | 2353     |
# |    total_timesteps  | 4792     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.6      |
# |    n_updates        | 947      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.0971   |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 2        |
# |    time_elapsed     | 2388     |
# |    total_timesteps  | 4872     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.47     |
# |    n_updates        | 967      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.0971   |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 2        |
# |    time_elapsed     | 2409     |
# |    total_timesteps  | 4909     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 5.7      |
# |    n_updates        | 977      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.097    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 2        |
# |    time_elapsed     | 2440     |
# |    total_timesteps  | 4979     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.981    |
# |    n_updates        | 994      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.097    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 2        |
# |    time_elapsed     | 2471     |
# |    total_timesteps  | 5048     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.94     |
# |    n_updates        | 1011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.097    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 2        |
# |    time_elapsed     | 2503     |
# |    total_timesteps  | 5118     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 5.79     |
# |    n_updates        | 1029     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.0969   |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 2        |
# |    time_elapsed     | 2526     |
# |    total_timesteps  | 5157     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 2.31     |
# |    n_updates        | 1039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.0969   |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 2        |
# |    time_elapsed     | 2556     |
# |    total_timesteps  | 5226     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 1.22     |
# |    n_updates        | 1056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.0968   |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 2        |
# |    time_elapsed     | 2590     |
# |    total_timesteps  | 5307     |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 2.6      |
# |    n_updates        | 1076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# ...
# |    time_elapsed     | 68460    |
# |    total_timesteps  | 166291   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 1.94     |
# |    n_updates        | 41322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30       |
# |    ep_rew_mean      | 30       |
# |    exploration_rate | 0.0012   |
# | time/               |          |
# |    episodes         | 6836     |
# |    fps              | 2        |
# |    time_elapsed     | 68520    |
# |    total_timesteps  | 166452   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 2.95     |
# |    n_updates        | 41362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.7     |
# |    ep_rew_mean      | 30.7     |
# |    exploration_rate | 0.00108  |
# | time/               |          |
# |    episodes         | 6840     |
# |    fps              | 2        |
# |    time_elapsed     | 68591    |
# |    total_timesteps  | 166648   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.478    |
# |    n_updates        | 41411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.6     |
# |    ep_rew_mean      | 30.6     |
# |    exploration_rate | 0.00102  |
# | time/               |          |
# |    episodes         | 6844     |
# |    fps              | 2        |
# |    time_elapsed     | 68635    |
# |    total_timesteps  | 166756   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.158    |
# |    n_updates        | 41438    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.4     |
# |    ep_rew_mean      | 30.4     |
# |    exploration_rate | 0.000974 |
# | time/               |          |
# |    episodes         | 6848     |
# |    fps              | 2        |
# |    time_elapsed     | 68667    |
# |    total_timesteps  | 166828   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.713    |
# |    n_updates        | 41456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 29.8     |
# |    exploration_rate | 0.000916 |
# | time/               |          |
# |    episodes         | 6852     |
# |    fps              | 2        |
# |    time_elapsed     | 68709    |
# |    total_timesteps  | 166926   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.805    |
# |    n_updates        | 41481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.000856 |
# | time/               |          |
# |    episodes         | 6856     |
# |    fps              | 2        |
# |    time_elapsed     | 68751    |
# |    total_timesteps  | 167026   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 5.68     |
# |    n_updates        | 41506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.4     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.000818 |
# | time/               |          |
# |    episodes         | 6860     |
# |    fps              | 2        |
# |    time_elapsed     | 68781    |
# |    total_timesteps  | 167091   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.947    |
# |    n_updates        | 41522    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.9     |
# |    ep_rew_mean      | 28.9     |
# |    exploration_rate | 0.000768 |
# | time/               |          |
# |    episodes         | 6864     |
# |    fps              | 2        |
# |    time_elapsed     | 68817    |
# |    total_timesteps  | 167174   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.208    |
# |    n_updates        | 41543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.9     |
# |    ep_rew_mean      | 28.9     |
# |    exploration_rate | 0.000714 |
# | time/               |          |
# |    episodes         | 6868     |
# |    fps              | 2        |
# |    time_elapsed     | 68855    |
# |    total_timesteps  | 167265   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.08     |
# |    n_updates        | 41566    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.4     |
# |    ep_rew_mean      | 28.4     |
# |    exploration_rate | 0.000679 |
# | time/               |          |
# |    episodes         | 6872     |
# |    fps              | 2        |
# |    time_elapsed     | 68883    |
# |    total_timesteps  | 167325   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.227    |
# |    n_updates        | 41581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.1     |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.000623 |
# | time/               |          |
# |    episodes         | 6876     |
# |    fps              | 2        |
# |    time_elapsed     | 68922    |
# |    total_timesteps  | 167419   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.447    |
# |    n_updates        | 41604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.5     |
# |    ep_rew_mean      | 28.5     |
# |    exploration_rate | 0.00057  |
# | time/               |          |
# |    episodes         | 6880     |
# |    fps              | 2        |
# |    time_elapsed     | 68959    |
# |    total_timesteps  | 167508   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.69     |
# |    n_updates        | 41626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.6     |
# |    ep_rew_mean      | 27.6     |
# |    exploration_rate | 0.00052  |
# | time/               |          |
# |    episodes         | 6884     |
# |    fps              | 2        |
# |    time_elapsed     | 68996    |
# |    total_timesteps  | 167593   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.26     |
# |    n_updates        | 41648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.9     |
# |    ep_rew_mean      | 27.9     |
# |    exploration_rate | 0.000454 |
# | time/               |          |
# |    episodes         | 6888     |
# |    fps              | 2        |
# |    time_elapsed     | 69040    |
# |    total_timesteps  | 167704   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 5.63     |
# |    n_updates        | 41675    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.000269 |
# | time/               |          |
# |    episodes         | 6892     |
# |    fps              | 2        |
# |    time_elapsed     | 69148    |
# |    total_timesteps  | 168015   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.97     |
# |    n_updates        | 41753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 29       |
# |    exploration_rate | 0.00022  |
# | time/               |          |
# |    episodes         | 6896     |
# |    fps              | 2        |
# |    time_elapsed     | 69183    |
# |    total_timesteps  | 168097   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 3.17     |
# |    n_updates        | 41774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | 28.7     |
# |    exploration_rate | 0.000167 |
# | time/               |          |
# |    episodes         | 6900     |
# |    fps              | 2        |
# |    time_elapsed     | 69220    |
# |    total_timesteps  | 168187   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 2.74     |
# |    n_updates        | 41796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.1     |
# |    ep_rew_mean      | 30.1     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6904     |
# |    fps              | 2        |
# |    time_elapsed     | 69302    |
# |    total_timesteps  | 168417   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 8.93     |
# |    n_updates        | 41854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.3     |
# |    ep_rew_mean      | 30.3     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6908     |
# |    fps              | 2        |
# |    time_elapsed     | 69352    |
# |    total_timesteps  | 168545   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 15.8     |
# |    n_updates        | 41886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 29.1     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6912     |
# |    fps              | 2        |
# |    time_elapsed     | 69400    |
# |    total_timesteps  | 168667   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 5.04     |
# |    n_updates        | 41916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 29       |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6916     |
# |    fps              | 2        |
# |    time_elapsed     | 69462    |
# |    total_timesteps  | 168835   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 4.99     |
# |    n_updates        | 41958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.7     |
# |    ep_rew_mean      | 28.7     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6920     |
# |    fps              | 2        |
# |    time_elapsed     | 69508    |
# |    total_timesteps  | 168951   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 5.85     |
# |    n_updates        | 41987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6924     |
# |    fps              | 2        |
# |    time_elapsed     | 69571    |
# |    total_timesteps  | 169119   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.129    |
# |    n_updates        | 42029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6928     |
# |    fps              | 2        |
# |    time_elapsed     | 69600    |
# |    total_timesteps  | 169180   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.148    |
# |    n_updates        | 42044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.5     |
# |    ep_rew_mean      | 30.5     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6932     |
# |    fps              | 2        |
# |    time_elapsed     | 69660    |
# |    total_timesteps  | 169339   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.06     |
# |    n_updates        | 42084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 29.8     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6936     |
# |    fps              | 2        |
# |    time_elapsed     | 69698    |
# |    total_timesteps  | 169427   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 2.28     |
# |    n_updates        | 42106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29       |
# |    ep_rew_mean      | 29       |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6940     |
# |    fps              | 2        |
# |    time_elapsed     | 69747    |
# |    total_timesteps  | 169551   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.21     |
# |    n_updates        | 42137    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.2     |
# |    ep_rew_mean      | 29.2     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6944     |
# |    fps              | 2        |
# |    time_elapsed     | 69797    |
# |    total_timesteps  | 169681   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 6.17     |
# |    n_updates        | 42170    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 29.7     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6948     |
# |    fps              | 2        |
# |    time_elapsed     | 69843    |
# |    total_timesteps  | 169794   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.654    |
# |    n_updates        | 42198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 30.3     |
# |    ep_rew_mean      | 30.3     |
# |    exploration_rate | 0.0001   |
# | time/               |          |
# |    episodes         | 6952     |
# |    fps              | 2        |
# |    time_elapsed     | 69905    |
# |    total_timesteps  | 169960   |
# | train/              |          |
# |    learning_rate    | 0.0006   |
# |    loss             | 0.182    |
# |    n_updates        | 42239    |
# ----------------------------------

# %%
# Saving the model
model.save("train/FlappyBird_DQN_Medium")
# Saving replay buffer
model.save_replay_buffer("train/buffer_FlappyBird_DQN_Medium")
