# %% [markdown]
# # Environment Setup

# %%
#!pip install gym gym-retro, opencv-python

# %%
# For monitoring agent
from stable_baselines3.common.monitor import Monitor
# To vectorize and frame stack
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack

# %%
# Running Environment_Setup.ipynb to setup custom Flappy_Bird environment.
# %run tools\Environment.py

# %%
LOG_DIR = './logs/'

# %%
# Creating environment 
env = Flappy_Bird()
env = Monitor(env, LOG_DIR)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, 4, channels_order='last')

# %% [markdown]
# # Setup Callback To Monitor Training Process

# %%
#!pip install stable-baselines3[extra]

# %%
# Import os for file path management
import os 
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'

# %%
callback = TrainAndLoggingCallback(check_freq=50_000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # Training Exploration Model

# %%
# Model
from stable_baselines3 import DQN

# %%
# parameters
parameters = {'buffer_size': 300_000, 
              'learning_starts': 2000, 
              'exploration_fraction': 0.01, 
              'exploration_final_eps': 0.04
             }

# %%
# Creating the model
model = DQN('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, **parameters)
# Out:
# Using cuda device

# %%
# Training the model
model.learn(total_timesteps=60_000, callback=callback)
# Out:
# Logging to ./logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.5      |
# |    ep_rew_mean      | 8.5      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1        |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.5      |
# |    ep_rew_mean      | 9.5      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1        |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1        |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 124      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1        |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 169      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1        |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 209      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1        |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 250      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1        |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 290      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1        |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 333      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1        |
# |    time_elapsed     | 199      |
# |    total_timesteps  | 372      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1        |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 414      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1        |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 457      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1        |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 496      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1        |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 536      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1        |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 579      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1        |
# |    time_elapsed     | 327      |
# |    total_timesteps  | 619      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1        |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 658      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1        |
# |    time_elapsed     | 370      |
# |    total_timesteps  | 698      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1        |
# |    time_elapsed     | 392      |
# |    total_timesteps  | 742      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1        |
# |    time_elapsed     | 414      |
# |    total_timesteps  | 786      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1        |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 827      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1        |
# |    time_elapsed     | 457      |
# |    total_timesteps  | 869      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1        |
# |    time_elapsed     | 478      |
# |    total_timesteps  | 909      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1        |
# |    time_elapsed     | 500      |
# |    total_timesteps  | 953      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1        |
# |    time_elapsed     | 521      |
# |    total_timesteps  | 994      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1        |
# |    time_elapsed     | 543      |
# |    total_timesteps  | 1036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1        |
# |    time_elapsed     | 565      |
# |    total_timesteps  | 1078     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1        |
# |    time_elapsed     | 586      |
# |    total_timesteps  | 1117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1        |
# |    time_elapsed     | 608      |
# |    total_timesteps  | 1160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1        |
# |    time_elapsed     | 629      |
# |    total_timesteps  | 1201     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1        |
# |    time_elapsed     | 651      |
# |    total_timesteps  | 1244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1        |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 1287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1        |
# |    time_elapsed     | 694      |
# |    total_timesteps  | 1327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1        |
# |    time_elapsed     | 716      |
# |    total_timesteps  | 1369     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1        |
# |    time_elapsed     | 738      |
# |    total_timesteps  | 1411     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1        |
# |    time_elapsed     | 759      |
# |    total_timesteps  | 1454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1        |
# |    time_elapsed     | 781      |
# |    total_timesteps  | 1496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1        |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 1535     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1        |
# |    time_elapsed     | 824      |
# |    total_timesteps  | 1576     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1        |
# |    time_elapsed     | 845      |
# |    total_timesteps  | 1618     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1        |
# |    time_elapsed     | 866      |
# |    total_timesteps  | 1657     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1        |
# |    time_elapsed     | 888      |
# |    total_timesteps  | 1699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1        |
# |    time_elapsed     | 909      |
# |    total_timesteps  | 1739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1        |
# |    time_elapsed     | 931      |
# |    total_timesteps  | 1784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1        |
# |    time_elapsed     | 954      |
# |    total_timesteps  | 1828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1        |
# |    time_elapsed     | 975      |
# |    total_timesteps  | 1869     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1        |
# |    time_elapsed     | 996      |
# |    total_timesteps  | 1908     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1        |
# |    time_elapsed     | 1018     |
# |    total_timesteps  | 1951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1        |
# |    time_elapsed     | 1039     |
# |    total_timesteps  | 1993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1        |
# |    time_elapsed     | 1066     |
# |    total_timesteps  | 2024     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.37     |
# |    n_updates        | 5        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1        |
# |    time_elapsed     | 1089     |
# |    total_timesteps  | 2069     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0947   |
# |    n_updates        | 17       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1        |
# |    time_elapsed     | 1112     |
# |    total_timesteps  | 2113     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.038    |
# |    n_updates        | 28       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1        |
# |    time_elapsed     | 1133     |
# |    total_timesteps  | 2153     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 38       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1        |
# |    time_elapsed     | 1155     |
# |    total_timesteps  | 2196     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00335  |
# |    n_updates        | 48       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1        |
# |    time_elapsed     | 1176     |
# |    total_timesteps  | 2236     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00045  |
# |    n_updates        | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1        |
# |    time_elapsed     | 1199     |
# |    total_timesteps  | 2279     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000608 |
# |    n_updates        | 69       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1        |
# |    time_elapsed     | 1221     |
# |    total_timesteps  | 2322     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000309 |
# |    n_updates        | 80       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1        |
# |    time_elapsed     | 1242     |
# |    total_timesteps  | 2362     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000326 |
# |    n_updates        | 90       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1        |
# |    time_elapsed     | 1263     |
# |    total_timesteps  | 2402     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000197 |
# |    n_updates        | 100      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1        |
# |    time_elapsed     | 1285     |
# |    total_timesteps  | 2444     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00024  |
# |    n_updates        | 110      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1        |
# |    time_elapsed     | 1307     |
# |    total_timesteps  | 2483     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000122 |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1        |
# |    time_elapsed     | 1329     |
# |    total_timesteps  | 2525     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000164 |
# |    n_updates        | 131      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1        |
# |    time_elapsed     | 1351     |
# |    total_timesteps  | 2567     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000124 |
# |    n_updates        | 141      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1        |
# |    time_elapsed     | 1372     |
# |    total_timesteps  | 2608     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00014  |
# |    n_updates        | 151      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1        |
# |    time_elapsed     | 1395     |
# |    total_timesteps  | 2652     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.52e-05 |
# |    n_updates        | 162      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1        |
# |    time_elapsed     | 1418     |
# |    total_timesteps  | 2698     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.58e-05 |
# |    n_updates        | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1        |
# |    time_elapsed     | 1440     |
# |    total_timesteps  | 2739     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.09e-05 |
# |    n_updates        | 184      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1        |
# |    time_elapsed     | 1461     |
# |    total_timesteps  | 2777     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000132 |
# |    n_updates        | 194      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1        |
# |    time_elapsed     | 1482     |
# |    total_timesteps  | 2818     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000113 |
# |    n_updates        | 204      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1        |
# |    time_elapsed     | 1504     |
# |    total_timesteps  | 2861     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.96e-05 |
# |    n_updates        | 215      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1        |
# |    time_elapsed     | 1526     |
# |    total_timesteps  | 2900     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000115 |
# |    n_updates        | 224      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1        |
# |    time_elapsed     | 1548     |
# |    total_timesteps  | 2943     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000153 |
# |    n_updates        | 235      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1        |
# |    time_elapsed     | 1570     |
# |    total_timesteps  | 2987     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.02e-05 |
# |    n_updates        | 246      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1        |
# |    time_elapsed     | 1591     |
# |    total_timesteps  | 3025     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.2e-05  |
# |    n_updates        | 256      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1        |
# |    time_elapsed     | 1612     |
# |    total_timesteps  | 3062     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.47e-05 |
# |    n_updates        | 265      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1        |
# |    time_elapsed     | 1634     |
# |    total_timesteps  | 3106     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.61e-05 |
# |    n_updates        | 276      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1        |
# |    time_elapsed     | 1656     |
# |    total_timesteps  | 3147     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.53e-05 |
# |    n_updates        | 286      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1        |
# |    time_elapsed     | 1677     |
# |    total_timesteps  | 3187     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.79e-05 |
# |    n_updates        | 296      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1        |
# |    time_elapsed     | 1699     |
# |    total_timesteps  | 3230     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000155 |
# |    n_updates        | 307      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1        |
# |    time_elapsed     | 1721     |
# |    total_timesteps  | 3271     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000215 |
# |    n_updates        | 317      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1        |
# |    time_elapsed     | 1743     |
# |    total_timesteps  | 3312     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000106 |
# |    n_updates        | 327      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1        |
# |    time_elapsed     | 1765     |
# |    total_timesteps  | 3355     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.97e-05 |
# |    n_updates        | 338      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1        |
# |    time_elapsed     | 1787     |
# |    total_timesteps  | 3398     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.78e-05 |
# |    n_updates        | 349      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1        |
# |    time_elapsed     | 1809     |
# |    total_timesteps  | 3438     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.67e-05 |
# |    n_updates        | 359      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1        |
# |    time_elapsed     | 1832     |
# |    total_timesteps  | 3486     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.3e-05  |
# |    n_updates        | 371      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1        |
# |    time_elapsed     | 1854     |
# |    total_timesteps  | 3528     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.49e-05 |
# |    n_updates        | 381      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1        |
# |    time_elapsed     | 1876     |
# |    total_timesteps  | 3570     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.26e-05 |
# |    n_updates        | 392      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1        |
# |    time_elapsed     | 1898     |
# |    total_timesteps  | 3611     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.65e-05 |
# |    n_updates        | 402      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1        |
# |    time_elapsed     | 1919     |
# |    total_timesteps  | 3649     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.08e-05 |
# |    n_updates        | 412      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1        |
# |    time_elapsed     | 1941     |
# |    total_timesteps  | 3689     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.87e-05 |
# |    n_updates        | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1        |
# |    time_elapsed     | 1963     |
# |    total_timesteps  | 3733     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.01e-05 |
# |    n_updates        | 433      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1        |
# |    time_elapsed     | 1985     |
# |    total_timesteps  | 3777     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.69e-05 |
# |    n_updates        | 444      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1        |
# |    time_elapsed     | 2007     |
# |    total_timesteps  | 3819     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.19e-05 |
# |    n_updates        | 454      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1        |
# |    time_elapsed     | 2029     |
# |    total_timesteps  | 3860     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.01e-05 |
# |    n_updates        | 464      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1        |
# |    time_elapsed     | 2051     |
# |    total_timesteps  | 3904     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.41e-05 |
# |    n_updates        | 475      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1        |
# |    time_elapsed     | 2073     |
# |    total_timesteps  | 3945     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.71e-05 |
# |    n_updates        | 486      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1        |
# |    time_elapsed     | 2095     |
# |    total_timesteps  | 3989     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.05e-05 |
# |    n_updates        | 497      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1        |
# |    time_elapsed     | 2118     |
# |    total_timesteps  | 4033     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.78e-05 |
# |    n_updates        | 508      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1        |
# |    time_elapsed     | 2140     |
# |    total_timesteps  | 4076     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.94e-05 |
# |    n_updates        | 518      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1        |
# |    time_elapsed     | 2161     |
# |    total_timesteps  | 4116     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.14e-05 |
# |    n_updates        | 528      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1        |
# |    time_elapsed     | 2182     |
# |    total_timesteps  | 4154     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.88e-05 |
# |    n_updates        | 538      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1        |
# |    time_elapsed     | 2205     |
# |    total_timesteps  | 4201     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.13e-05 |
# |    n_updates        | 550      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.815    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1        |
# |    time_elapsed     | 2226     |
# |    total_timesteps  | 4240     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.17e-05 |
# |    n_updates        | 559      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1        |
# |    time_elapsed     | 2248     |
# |    total_timesteps  | 4281     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.7e-05  |
# |    n_updates        | 570      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1        |
# |    time_elapsed     | 2269     |
# |    total_timesteps  | 4320     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.2e-05  |
# |    n_updates        | 579      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.95     |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6760     |
# |    fps              | 1        |
# |    time_elapsed     | 35850    |
# |    total_timesteps  | 62600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 15149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6764     |
# |    fps              | 1        |
# |    time_elapsed     | 35872    |
# |    total_timesteps  | 62640    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0317   |
# |    n_updates        | 15159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6768     |
# |    fps              | 1        |
# |    time_elapsed     | 35894    |
# |    total_timesteps  | 62679    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0298   |
# |    n_updates        | 15169    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6772     |
# |    fps              | 1        |
# |    time_elapsed     | 35916    |
# |    total_timesteps  | 62719    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0541   |
# |    n_updates        | 15179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6776     |
# |    fps              | 1        |
# |    time_elapsed     | 35938    |
# |    total_timesteps  | 62759    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 15189    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6780     |
# |    fps              | 1        |
# |    time_elapsed     | 35960    |
# |    total_timesteps  | 62799    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 15199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6784     |
# |    fps              | 1        |
# |    time_elapsed     | 35982    |
# |    total_timesteps  | 62839    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0489   |
# |    n_updates        | 15209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6788     |
# |    fps              | 1        |
# |    time_elapsed     | 36004    |
# |    total_timesteps  | 62879    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0446   |
# |    n_updates        | 15219    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.92     |
# |    ep_rew_mean      | 9.92     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6792     |
# |    fps              | 1        |
# |    time_elapsed     | 36026    |
# |    total_timesteps  | 62918    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 15229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.93     |
# |    ep_rew_mean      | 9.93     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6796     |
# |    fps              | 1        |
# |    time_elapsed     | 36049    |
# |    total_timesteps  | 62958    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0363   |
# |    n_updates        | 15239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.95     |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6800     |
# |    fps              | 1        |
# |    time_elapsed     | 36071    |
# |    total_timesteps  | 62998    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0603   |
# |    n_updates        | 15249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.95     |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6804     |
# |    fps              | 1        |
# |    time_elapsed     | 36093    |
# |    total_timesteps  | 63038    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 15259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.96     |
# |    ep_rew_mean      | 9.96     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6808     |
# |    fps              | 1        |
# |    time_elapsed     | 36115    |
# |    total_timesteps  | 63079    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0385   |
# |    n_updates        | 15269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.96     |
# |    ep_rew_mean      | 9.96     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6812     |
# |    fps              | 1        |
# |    time_elapsed     | 36137    |
# |    total_timesteps  | 63119    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0498   |
# |    n_updates        | 15279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.98     |
# |    ep_rew_mean      | 9.98     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6816     |
# |    fps              | 1        |
# |    time_elapsed     | 36159    |
# |    total_timesteps  | 63159    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.047    |
# |    n_updates        | 15289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.95     |
# |    ep_rew_mean      | 9.95     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6820     |
# |    fps              | 1        |
# |    time_elapsed     | 36181    |
# |    total_timesteps  | 63199    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0369   |
# |    n_updates        | 15299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.92     |
# |    ep_rew_mean      | 9.92     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6824     |
# |    fps              | 1        |
# |    time_elapsed     | 36203    |
# |    total_timesteps  | 63238    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0588   |
# |    n_updates        | 15309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.92     |
# |    ep_rew_mean      | 9.92     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6828     |
# |    fps              | 1        |
# |    time_elapsed     | 36225    |
# |    total_timesteps  | 63277    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0694   |
# |    n_updates        | 15319    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6832     |
# |    fps              | 1        |
# |    time_elapsed     | 36247    |
# |    total_timesteps  | 63317    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0575   |
# |    n_updates        | 15329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 9.94     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6836     |
# |    fps              | 1        |
# |    time_elapsed     | 36270    |
# |    total_timesteps  | 63357    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0591   |
# |    n_updates        | 15339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.93     |
# |    ep_rew_mean      | 9.93     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6840     |
# |    fps              | 1        |
# |    time_elapsed     | 36292    |
# |    total_timesteps  | 63396    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 15348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.92     |
# |    ep_rew_mean      | 9.92     |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 6844     |
# |    fps              | 1        |
# |    time_elapsed     | 36314    |
# |    total_timesteps  | 63435    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 15358    |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 # Training the model
# ----> 2 model.learn(total_timesteps=220_000, callback=callback)
#
# File ~\anaconda3\envs\RL46\lib\site-packages\stable_baselines3\dqn\dqn.py:275, in DQN.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     261 def learn(
#     262     self: DQNSelf,
#     263     total_timesteps: int,
#    (...)
#     272     progress_bar: bool = False,
#     273 ) -> DQNSelf:
# --> 275     return super().learn(
#     276         total_timesteps=total_timesteps,
#     277         callback=callback,
#     278         log_interval=log_interval,
#     279         eval_env=eval_env,
#     280         eval_freq=eval_freq,
#     281         n_eval_episodes=n_eval_episodes,
#     282         tb_log_name=tb_log_name,
#     283         eval_log_path=eval_log_path,
#     284         reset_num_timesteps=reset_num_timesteps,
#     285         progress_bar=progress_bar,
#     286     )
#
# File ~\anaconda3\envs\RL46\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:356, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     353 callback.on_training_start(locals(), globals())
#     355 while self.num_timesteps < total_timesteps:
# --> 356     rollout = self.collect_rollouts(
#     357         self.env,
#     358         train_freq=self.train_freq,
#     359         action_noise=self.action_noise,
#     360         callback=callback,
#     361         learning_starts=self.learning_starts,
#     362         replay_buffer=self.replay_buffer,
#     363         log_interval=log_interval,
#     364     )
#     366     if rollout.continue_training is False:
#     367         break
#
# File ~\anaconda3\envs\RL46\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:589, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     586 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     588 # Rescale and perform action
# --> 589 new_obs, rewards, dones, infos = env.step(actions)
#     591 self.num_timesteps += env.num_envs
#     592 num_collected_steps += 1
#
# File ~\anaconda3\envs\RL46\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File ~\anaconda3\envs\RL46\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py:48, in VecFrameStack.step_wait(self)
#      44 def step_wait(
#      45     self,
#      46 ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
# ---> 48     observations, rewards, dones, infos = self.venv.step_wait()
#      50     observations, infos = self.stackedobs.update(observations, dones, infos)
#      52     return observations, rewards, dones, infos
#
# File ~\anaconda3\envs\RL46\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:49, in DummyVecEnv.step_wait(self)
#      46     if self.buf_dones[env_idx]:
#      47         # save final observation where user can get it, then reset
#      48         self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 49         obs = self.envs[env_idx].reset()
#      50     self._save_obs(env_idx, obs)
#      51 return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# File ~\anaconda3\envs\RL46\lib\site-packages\stable_baselines3\common\monitor.py:83, in Monitor.reset(self, **kwargs)
#      81         raise ValueError(f"Expected you to pass keyword argument {key} into reset")
#      82     self.current_reset_info[key] = value
# ---> 83 return self.env.reset(**kwargs)
#
# File ~\aDesktop\Pulpit\Flappy bird\tools\Environment.py:46, in Flappy_Bird.reset(self)
#      44 def reset(self):
#      45     # Reseting game
# ---> 46     time.sleep(2)
#      47     for _ in range(3):
#      48         time.sleep(0.08)
#
# KeyboardInterrupt:

# %%
# Saving the model
model.save("train/DQN-FlappyBird.zip")
